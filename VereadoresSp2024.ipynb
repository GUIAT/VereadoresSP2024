# %% [markdown]
# Origem dos dados : https://divulgacandcontas.tse.jus.br/divulga/#/candidato/SUDESTE/SP/2045202024

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

candidatos = pd.read_excel("CANDIDATOS-SP-2024-10-04T13_57_52.761Z.xlsx")
candidatos.head()
# Out:
#               Nome Urna      Coligação  Totalização  Partido
# 0           100 MIZÉRIA  SOLIDARIEDADE  Concorrendo    77100
# 1          ABDUL JAROUR            PSB  Concorrendo    40999
# 2             ABOU ANNI           PODE  Concorrendo    20007
# 3          ADAM MAAMARI             PL  Concorrendo    22007
# 4  ADAUTO DO TRANSPORTE         AVANTE  Concorrendo    70555

# %%
nbColigacao = candidatos["Coligação"].value_counts()
nmCologacao = candidatos["Coligação"].unique()

# plot
fig, ax = plt.subplots()

p = ax.bar(nmCologacao, nbColigacao)

labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
ax.bar_label(p)

ax.set_ylabel('Quantidade de candidatos')
ax.set_title('Quantidade de candidatos por partidos - Elecoes Sao Paulo/SP 2024')

plt.show()

# %%
fig.savefig('CandidatosPorPartido.png')
